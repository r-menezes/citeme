# %% [markdown]
# ## Exemplificação da utilização da busca semântica

# %%
import numpy as np
import pandas as pd

from corpus_embed import CorpusEmbed
from clean_and_divide_sentences import create_sentence_df

# %%
df = pd.read_parquet("data/sentence_bioPE_corpus.parquet")

# %%
df.describe()
# Out:
#                 id          authors                           doi categories  \
# count        98236            98236                         40419      98236
# unique       11354            10044                          4689       1723
# top     1707.02447  Steven A. Frank  10.1016/j.epidem.2021.100530   q-bio.PE
# freq            81              420                            39      27834
#
#        update_date                                              title sentence
# count        98236                                              98236    98236
# unique        3508                                              11352    95905
# top     2007-05-23  Pediatric hospitalizations associated with res...        e
# freq          3703                                                 81      739

# %%
df = df.sample(n=1000)

# %%
emb_npy = np.load("data/embeddings.npy")

# %%
emb = CorpusEmbed(model="allenai-specter",
                sentence_df=df)
# Out:
# Loading model...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/allenai-specter
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Computing embeddings...
# Storing embeddings...
# Done!

# %%
emb.save_embeddings()
# Out:
# Saving embeddings to data/embeddings.npy and metadata to data/embeddings_metadata.parquet
# Done!

# %%
emb.search_reference("A well mixed model does not take into account the spatial distribution of the population")
# Out:
# Phrase: A well mixed model does not take into account the spatial distribution of the population
# Related papers:
#
# ----------
# Similarity: 0.9046874046325684
# Title: Spatial Population Genetics: It's About Time
# Authors: Gideon S. Bradburd and Peter L. Ralph
# 2019-11-28
# DOI: https://doi.org/10.1146/annurev-ecolsys-110316-022659
# arXiV: https://arxiv.org/abs/1904.09847
# Sentence: We also highlight some current methods and gaps in the statistical toolbox of spatial population genetics
# ----------
#
# ----------
# Similarity: 0.8992739915847778
# Title: Spontaneous emergence of spatial patterns ina a predator-prey model
# Authors: I. C. Charret and M. V. Carneiro
# 2007-12-18
# DOI: https://doi.org/10.1103/PhysRevE.76.061902
# arXiV: https://arxiv.org/abs/q-bio/0611024
# Sentence: We focus on the pattern formation in the spatial distributions of the populations
# ----------
#
# ----------
# Similarity: 0.891730546951294
# Title: Eco-evolutionary dynamics and collective dispersal: implications for   salmon metapopulation robustness
# Authors: Justin D. Yeakel, Jean P. Gibert, Peter A. H. Westley, Jonathan W.
#   Moore
# 2017-09-25
# DOI: https://doi.org/nan
# arXiV: https://arxiv.org/abs/1709.07515
# Sentence: The spatial dispersal of individuals is known to play an important role in the dynamics of populations, and is central to metapopulation theory
# ----------
#
# ----------
# Similarity: 0.890654444694519
# Title: Bayesian Analysis of Partitioned Data
# Authors: Brian R. Moore, Jim McGuire, Fredrik Ronquist, and John P. Huelsenbeck
# 2014-09-04
# DOI: https://doi.org/nan
# arXiV: https://arxiv.org/abs/1409.0906
# Sentence: We apply this method to simulated and empirical datasets, and compare our results to those estimated previously using conventional mixed-model selection criteria based on Bayes factors
# ----------
#
# ----------
# Similarity: 0.8831228613853455
# Title: Bayesian Method for Disease QTL Detection and Mapping, using a Case and   Control Design and DNA Pooling
# Authors: Toby Johnson
# 2008-02-21
# DOI: https://doi.org/10.1093/biostatistics/kxl028
# arXiV: https://arxiv.org/abs/q-bio/0507018
# Sentence: The method works by conducting an exact Bayesian analysis under a number of simplifying population genetic assumptions that are somewhat unrealistic
# ----------
#
# ----------
# Similarity: 0.8759503960609436
# Title: Modular knowledge systems accelerate human migration in asymmetric   random environments
# Authors: Dong Wang and Michael W. Deem
# 2016-12-07
# DOI: https://doi.org/nan
# arXiV: https://arxiv.org/abs/1612.01910
# Sentence: For historical human migration, environmental heterogeneity was naturally asymmetric in the north-south (NS) and east-west (EW) directions
# ----------
#
# ----------
# Similarity: 0.8722470998764038
# Title: Agentization of Two Population-Driven Models of Mathematical Biology
# Authors: John C. Stevenson
# 2021-09-21
# DOI: https://doi.org/nan
# arXiV: https://arxiv.org/abs/2108.08916
# Sentence: For the population models, the requirement of homogeneous mixing prevents prediction of extinctions due to local resource depletion
# ----------

# %%
# get metadata
df.iloc[41].sentence
# Out:
# 'The living-together of distinct organisms in a single termite nest along with the termite builder colony, is emblematic in its ecological and evolutionary significance'
